# %% [markdown]
# # Kiran Avhad

# %% [markdown]
# # Task 6:-Timeline analysis:-Covid 19

# %% [markdown]
# # Importing Libraries

# %%
# !pip install pylab
# Out:
# ERROR: Could not find a version that satisfies the requirement pylab (from versions: none)
# ERROR: No matching distribution found for pylab

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl
# %matplotlib inline
sns.set()

# %% [markdown]
# # Reading data

# %%
df=pd.read_csv("D:/FILM/owid-covid-data.csv")
df
# Out:
# D:\kiran imp softwares\New folder\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (1,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  13/03/2020          2.0
# 1          ABW  North America          Aruba  19/03/2020          NaN
# 2          ABW  North America          Aruba  20/03/2020          4.0
# 3          ABW  North America          Aruba  21/03/2020          NaN
# 4          ABW  North America          Aruba  22/03/2020          NaN
# ...        ...            ...            ...         ...          ...
# 49663      NaN            NaN  International  08/10/2020        696.0
# 49664      NaN            NaN  International  09/10/2020        696.0
# 49665      NaN            NaN  International  10/10/2020        696.0
# 49666      NaN            NaN  International  11/10/2020        696.0
# 49667      NaN            NaN  International  12/10/2020        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           0.0         0.0
# 1            NaN               0.286           NaN         NaN
# 2            2.0               0.286           0.0         0.0
# 3            NaN               0.286           NaN         NaN
# 4            NaN               0.286           NaN         NaN
# ...          ...                 ...           ...         ...
# 49663        NaN                 NaN           7.0         NaN
# 49664        NaN                 NaN           7.0         NaN
# 49665        NaN                 NaN           7.0         NaN
# 49666        NaN                 NaN           7.0         NaN
# 49667        NaN                 NaN           7.0         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 0                      NaN  ...       35973.781              NaN
# 1                      0.0  ...       35973.781              NaN
# 2                      0.0  ...       35973.781              NaN
# 3                      0.0  ...       35973.781              NaN
# 4                      0.0  ...       35973.781              NaN
# ...                    ...  ...             ...              ...
# 49663                  NaN  ...             NaN              NaN
# 49664                  NaN  ...             NaN              NaN
# 49665                  NaN  ...             NaN              NaN
# 49666                  NaN  ...             NaN              NaN
# 49667                  NaN  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 0                        NaN                11.62             NaN
# 1                        NaN                11.62             NaN
# 2                        NaN                11.62             NaN
# 3                        NaN                11.62             NaN
# 4                        NaN                11.62             NaN
# ...                      ...                  ...             ...
# 49663                    NaN                  NaN             NaN
# 49664                    NaN                  NaN             NaN
# 49665                    NaN                  NaN             NaN
# 49666                    NaN                  NaN             NaN
# 49667                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0               NaN                     NaN                         NaN
# 1               NaN                     NaN                         NaN
# 2               NaN                     NaN                         NaN
# 3               NaN                     NaN                         NaN
# 4               NaN                     NaN                         NaN
# ...             ...                     ...                         ...
# 49663           NaN                     NaN                         NaN
# 49664           NaN                     NaN                         NaN
# 49665           NaN                     NaN                         NaN
# 49666           NaN                     NaN                         NaN
# 49667           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 0                76.29                      NaN
# 1                76.29                      NaN
# 2                76.29                      NaN
# 3                76.29                      NaN
# 4                76.29                      NaN
# ...                ...                      ...
# 49663              NaN                      NaN
# 49664              NaN                      NaN
# 49665              NaN                      NaN
# 49666              NaN                      NaN
# 49667              NaN                      NaN
#
# [49668 rows x 41 columns]

# %%
df.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  13/03/2020          2.0        2.0
# 1      ABW  North America    Aruba  19/03/2020          NaN        NaN
# 2      ABW  North America    Aruba  20/03/2020          4.0        2.0
# 3      ABW  North America    Aruba  21/03/2020          NaN        NaN
# 4      ABW  North America    Aruba  22/03/2020          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       35973.781              NaN                    NaN
# 1       35973.781              NaN                    NaN
# 2       35973.781              NaN                    NaN
# 3       35973.781              NaN                    NaN
# 4       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                11.62             NaN           NaN                     NaN
# 1                11.62             NaN           NaN                     NaN
# 2                11.62             NaN           NaN                     NaN
# 3                11.62             NaN           NaN                     NaN
# 4                11.62             NaN           NaN                     NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         NaN            76.29                      NaN
# 1                         NaN            76.29                      NaN
# 2                         NaN            76.29                      NaN
# 3                         NaN            76.29                      NaN
# 4                         NaN            76.29                      NaN
#
# [5 rows x 41 columns]

# %%
df.tail()
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 49663      NaN       NaN  International  08/10/2020        696.0        NaN
# 49664      NaN       NaN  International  09/10/2020        696.0        NaN
# 49665      NaN       NaN  International  10/10/2020        696.0        NaN
# 49666      NaN       NaN  International  11/10/2020        696.0        NaN
# 49667      NaN       NaN  International  12/10/2020        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49663                 NaN           7.0         NaN                  NaN  ...
# 49664                 NaN           7.0         NaN                  NaN  ...
# 49665                 NaN           7.0         NaN                  NaN  ...
# 49666                 NaN           7.0         NaN                  NaN  ...
# 49667                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 49663             NaN              NaN                    NaN
# 49664             NaN              NaN                    NaN
# 49665             NaN              NaN                    NaN
# 49666             NaN              NaN                    NaN
# 49667             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 49663                  NaN             NaN           NaN
# 49664                  NaN             NaN           NaN
# 49665                  NaN             NaN           NaN
# 49666                  NaN             NaN           NaN
# 49667                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 49663                     NaN                         NaN              NaN
# 49664                     NaN                         NaN              NaN
# 49665                     NaN                         NaN              NaN
# 49666                     NaN                         NaN              NaN
# 49667                     NaN                         NaN              NaN
#
#        human_development_index
# 49663                      NaN
# 49664                      NaN
# 49665                      NaN
# 49666                      NaN
# 49667                      NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# # Data Exploration

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  4.903200e+04   48809.000000        48027.000000  4.903200e+04
# mean   1.164479e+05    1539.422770         1523.171677  4.454314e+03
# std    1.203765e+06   13899.994619        13661.787655  4.127713e+04
# min    0.000000e+00   -8261.000000         -552.000000  0.000000e+00
# 25%    7.100000e+01       0.000000            0.714000  1.000000e+00
# 50%    1.176000e+03      11.000000           16.286000  2.300000e+01
# 75%    1.310625e+04     179.000000          185.857000  2.730000e+02
# max    3.756884e+07  387487.000000       328458.286000  1.077508e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  48809.000000         48027.000000             48745.000000
# mean      44.152021            44.189808              2154.172539
# std      370.378116           359.720383              4469.638599
# min    -1918.000000          -232.143000                 0.000000
# 25%        0.000000             0.000000                38.630000
# 50%        0.000000             0.286000               320.144000
# 75%        3.000000             3.286000              2235.074000
# max    10491.000000          7456.857000             44422.886000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           48745.000000                    47962.000000
# mean               26.827541                       26.372757
# std                80.406292                       61.493288
# min             -2212.545000                     -269.978000
# 25%                 0.000000                        0.174000
# 50%                 1.705000                        3.234000
# 75%                19.790000                       22.004500
# max              4944.376000                     1083.470000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              48745.000000  ...    43681.000000     29130.000000
# mean                  62.267456  ...    20833.200479        12.206993
# std                  148.969472  ...    20401.154967        19.286532
# min                    0.000000  ...      661.240000         0.100000
# 25%                    0.062000  ...     5338.454000         0.500000
# 50%                    5.716000  ...    14048.881000         2.000000
# 75%                   41.128000  ...    31400.840000        18.100000
# max                 1237.551000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           44247.000000         45835.000000    34603.000000
# mean              251.808480             8.050365       10.792369
# std               117.457364             4.150900       10.476221
# min                79.370000             0.990000        0.100000
# 25%               155.898000             5.310000        1.900000
# 50%               238.339000             7.110000        6.400000
# 75%               318.991000            10.390000       19.600000
# max               724.417000            23.360000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  34162.000000            20779.000000                39933.000000
# mean      32.636416               52.341902                    3.105424
# std       13.428314               31.621293                    2.523176
# min        7.700000                1.188000                    0.100000
# 25%       21.400000               21.222000                    1.300000
# 50%       31.400000               52.232000                    2.500000
# 75%       40.900000               83.741000                    4.200000
# max       78.100000               98.999000                   13.800000
#
#        life_expectancy  human_development_index
# count     48754.000000             42705.000000
# mean         74.000864                 0.724175
# std           7.382057                 0.152973
# min          53.280000                 0.354000
# 25%          69.870000                 0.606000
# 50%          75.400000                 0.754000
# 75%          79.380000                 0.847000
# max          86.750000                 0.953000
#
# [8 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49668 entries, 0 to 49667
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         49381 non-null  object
#  1   continent                        49094 non-null  object
#  2   location                         49668 non-null  object
#  3   date                             49668 non-null  object
#  4   total_cases                      49032 non-null  float64
#  5   new_cases                        48809 non-null  float64
#  6   new_cases_smoothed               48027 non-null  float64
#  7   total_deaths                     49032 non-null  float64
#  8   new_deaths                       48809 non-null  float64
#  9   new_deaths_smoothed              48027 non-null  float64
#  10  total_cases_per_million          48745 non-null  float64
#  11  new_cases_per_million            48745 non-null  float64
#  12  new_cases_smoothed_per_million   47962 non-null  float64
#  13  total_deaths_per_million         48745 non-null  float64
#  14  new_deaths_per_million           48745 non-null  float64
#  15  new_deaths_smoothed_per_million  47962 non-null  float64
#  16  new_tests                        18046 non-null  float64
#  17  total_tests                      18465 non-null  float64
#  18  total_tests_per_thousand         18465 non-null  float64
#  19  new_tests_per_thousand           18046 non-null  float64
#  20  new_tests_smoothed               20417 non-null  float64
#  21  new_tests_smoothed_per_thousand  20417 non-null  float64
#  22  tests_per_case                   18810 non-null  float64
#  23  positive_rate                    19270 non-null  float64
#  24  tests_units                      21272 non-null  object
#  25  stringency_index                 41070 non-null  float64
#  26  population                       49381 non-null  float64
#  27  population_density               47109 non-null  float64
#  28  median_age                       44260 non-null  float64
#  29  aged_65_older                    43599 non-null  float64
#  30  aged_70_older                    44030 non-null  float64
#  31  gdp_per_capita                   43681 non-null  float64
#  32  extreme_poverty                  29130 non-null  float64
#  33  cardiovasc_death_rate            44247 non-null  float64
#  34  diabetes_prevalence              45835 non-null  float64
#  35  female_smokers                   34603 non-null  float64
#  36  male_smokers                     34162 non-null  float64
#  37  handwashing_facilities           20779 non-null  float64
#  38  hospital_beds_per_thousand       39933 non-null  float64
#  39  life_expectancy                  48754 non-null  float64
#  40  human_development_index          42705 non-null  float64
# dtypes: float64(36), object(5)
# memory usage: 15.5+ MB

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
df.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  13/03/2020          2.0        2.0
# 1      ABW  North America    Aruba  19/03/2020          NaN        NaN
# 2      ABW  North America    Aruba  20/03/2020          4.0        2.0
# 3      ABW  North America    Aruba  21/03/2020          NaN        NaN
# 4      ABW  North America    Aruba  22/03/2020          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       35973.781              NaN                    NaN
# 1       35973.781              NaN                    NaN
# 2       35973.781              NaN                    NaN
# 3       35973.781              NaN                    NaN
# 4       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                11.62             NaN           NaN                     NaN
# 1                11.62             NaN           NaN                     NaN
# 2                11.62             NaN           NaN                     NaN
# 3                11.62             NaN           NaN                     NaN
# 4                11.62             NaN           NaN                     NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         NaN            76.29                      NaN
# 1                         NaN            76.29                      NaN
# 2                         NaN            76.29                      NaN
# 3                         NaN            76.29                      NaN
# 4                         NaN            76.29                      NaN
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (49668, 41)

# %%
duplicate_rows_df=df[df.duplicated()]
print("no of duplicate raws=",duplicate_rows_df.shape)
# Out:
# no of duplicate raws= (0, 41)

# %%
df.count()
# Out:
# iso_code                           49381
# continent                          49094
# location                           49668
# date                               49668
# total_cases                        49032
# new_cases                          48809
# new_cases_smoothed                 48027
# total_deaths                       49032
# new_deaths                         48809
# new_deaths_smoothed                48027
# total_cases_per_million            48745
# new_cases_per_million              48745
# new_cases_smoothed_per_million     47962
# total_deaths_per_million           48745
# new_deaths_per_million             48745
# new_deaths_smoothed_per_million    47962
# new_tests                          18046
# total_tests                        18465
# total_tests_per_thousand           18465
# new_tests_per_thousand             18046
# new_tests_smoothed                 20417
# new_tests_smoothed_per_thousand    20417
# tests_per_case                     18810
# positive_rate                      19270
# tests_units                        21272
# stringency_index                   41070
# population                         49381
# population_density                 47109
# median_age                         44260
# aged_65_older                      43599
# aged_70_older                      44030
# gdp_per_capita                     43681
# extreme_poverty                    29130
# cardiovasc_death_rate              44247
# diabetes_prevalence                45835
# female_smokers                     34603
# male_smokers                       34162
# handwashing_facilities             20779
# hospital_beds_per_thousand         39933
# life_expectancy                    48754
# human_development_index            42705
# dtype: int64

# %%
df.isnull().sum()
# Out:
# iso_code                             287
# continent                            574
# location                               0
# date                                   0
# total_cases                          636
# new_cases                            859
# new_cases_smoothed                  1641
# total_deaths                         636
# new_deaths                           859
# new_deaths_smoothed                 1641
# total_cases_per_million              923
# new_cases_per_million                923
# new_cases_smoothed_per_million      1706
# total_deaths_per_million             923
# new_deaths_per_million               923
# new_deaths_smoothed_per_million     1706
# new_tests                          31622
# total_tests                        31203
# total_tests_per_thousand           31203
# new_tests_per_thousand             31622
# new_tests_smoothed                 29251
# new_tests_smoothed_per_thousand    29251
# tests_per_case                     30858
# positive_rate                      30398
# tests_units                        28396
# stringency_index                    8598
# population                           287
# population_density                  2559
# median_age                          5408
# aged_65_older                       6069
# aged_70_older                       5638
# gdp_per_capita                      5987
# extreme_poverty                    20538
# cardiovasc_death_rate               5421
# diabetes_prevalence                 3833
# female_smokers                     15065
# male_smokers                       15506
# handwashing_facilities             28889
# hospital_beds_per_thousand          9735
# life_expectancy                      914
# human_development_index             6963
# dtype: int64

# %%
df1=df[["date","total_cases","new_cases","total_deaths","new_tests","total_tests"]]
df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  13/03/2020          2.0        2.0           0.0        NaN          NaN
# 1  19/03/2020          NaN        NaN           NaN        NaN          NaN
# 2  20/03/2020          4.0        2.0           0.0        NaN          NaN
# 3  21/03/2020          NaN        NaN           NaN        NaN          NaN
# 4  22/03/2020          NaN        NaN           NaN        NaN          NaN

# %%
df1.date=pd.to_datetime(df.date)
df1.set_index("date",inplace=True)
# Out:
# D:\kiran imp softwares\New folder\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df1.head()
# Out:
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2020-03-13          2.0        2.0           0.0        NaN          NaN
# 2020-03-19          NaN        NaN           NaN        NaN          NaN
# 2020-03-20          4.0        2.0           0.0        NaN          NaN
# 2020-03-21          NaN        NaN           NaN        NaN          NaN
# 2020-03-22          NaN        NaN           NaN        NaN          NaN

# %%
df1.tail()
# Out:
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2020-08-10        696.0        NaN           7.0        NaN          NaN
# 2020-09-10        696.0        NaN           7.0        NaN          NaN
# 2020-10-10        696.0        NaN           7.0        NaN          NaN
# 2020-11-10        696.0        NaN           7.0        NaN          NaN
# 2020-12-10        696.0        NaN           7.0        NaN          NaN

# %%
df1.describe()
# Out:
#         total_cases      new_cases  total_deaths     new_tests   total_tests
# count  4.903200e+04   48809.000000  4.903200e+04  1.804600e+04  1.846500e+04
# mean   1.164479e+05    1539.422770  4.454314e+03  2.456612e+04  1.718175e+06
# std    1.203765e+06   13899.994619  4.127713e+04  1.011755e+05  7.798625e+06
# min    0.000000e+00   -8261.000000  0.000000e+00 -4.429000e+03  1.000000e+00
# 25%    7.100000e+01       0.000000  1.000000e+00  9.940000e+02  5.027800e+04
# 50%    1.176000e+03      11.000000  2.300000e+01  3.411000e+03  2.144770e+05
# 75%    1.310625e+04     179.000000  2.730000e+02  1.256400e+04  8.509350e+05
# max    3.756884e+07  387487.000000  1.077508e+06  1.492409e+06  1.254384e+08

# %%
df1.mean()
# Out:
# total_cases     1.164479e+05
# new_cases       1.539423e+03
# total_deaths    4.454314e+03
# new_tests       2.456612e+04
# total_tests     1.718175e+06
# dtype: float64

# %%
df1.shape
# Out:
# (49668, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 49668 entries, 2020-03-13 to 2020-12-10
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   total_cases   49032 non-null  float64
#  1   new_cases     48809 non-null  float64
#  2   total_deaths  49032 non-null  float64
#  3   new_tests     18046 non-null  float64
#  4   total_tests   18465 non-null  float64
# dtypes: float64(5)
# memory usage: 2.3 MB

# %% [markdown]
# # Data Visualization

# %%
sns.distplot(df1['total_cases'])
sns.distplot(df1['new_cases']);

# %%
sns.distplot(df1['total_tests'])
sns.distplot(df1['new_tests']);

# %%
sns.pairplot(df1, size=2.5);
# Out:
# D:\kiran imp softwares\New folder\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
with sns.axes_style('white'):
    sns.jointplot("new_cases", "total_cases", data=df1, kind='reg')

# %%
sns.distplot(df1['total_cases'], kde=False);
plt.axvline(0, color="k", linestyle="--");

# %%
sns.distplot(df1['new_cases'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
sns.distplot(df1['new_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
sns.distplot(df1['total_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %% [markdown]
# # Timeseries Analysis Of covid 19

# %%
df1.total_cases.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.new_cases.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.new_tests.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_tests.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_cases=df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_deaths=df1[['total_deaths']]
total_deaths.rolling(12).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
new_test=df1[['new_tests']]
new_test.rolling(12).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_test=df1[['total_tests']]
total_test.rolling(12).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_cases=df1[['total_cases']]
total_cases.rolling(10).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')
